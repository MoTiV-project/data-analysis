# %%
from docx import Document
from docx.shared import Inches
import pathlib

from IPython.core.display import display, HTML

display(HTML("<style>.container { width:95% !important; }</style"))

img_path = pathlib.Path("../../2019-12-16.out/D5.1/images/")
report_path = pathlib.Path("../../2019-12-16.out/D5.1/")
# Out:
# <style>.container { width:95% !important; }</style

# %%
## Initial information
document = Document()
document.add_heading("D5.1 Analyses")
subtitle = "Additional analyses for deliverable D5.1."
document.add_heading(subtitle, level=2)

width = Inches(6.0)

# %%
### Q1
p = document.add_heading(
    "Q1: Number of trips pre and post clarification of the difference "
    "between worthwhileness at destionation and during trip."
)

document.add_paragraph(
    "Distribution of Worthwhileness ratings per trip pre-clarification "
    "between Worthwhileness at destination and Worthwhileness of trip."
)
document.add_picture(
    str(img_path / "D5.1_worthwhileness_rating_tc_pre.png"), width=width
)


document.add_paragraph(
    "Distribution of Worthwhileness ratings per trip post-clarification "
    "between Worthwhileness at destination and Worthwhileness of trip."
)
document.add_picture(
    str(img_path / "D5.1_worthwhileness_rating_tc_post.png"), width=width
)

# %%
document.save(report_path / "D5.1_analyses.docx")
